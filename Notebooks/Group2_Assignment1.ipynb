# %% [markdown]
# # Group Two
# | Student name | ID |
# |---|---:|
# | Senay Teweldebrhan | 9120588 |
# | Juan Camilo Chirivi | 9115141 |
# | Zeynep Ozdemir | 9045142 |

# %% [markdown]
# ## Setup and configuration
# Run the cell below before running the rest of the notebook. (We need to complete after completing project )

# %% [markdown]
# ## Data cleansing and feature engineering
#
# Before analysis, we will check the dataset for missing values, inconsistent
# data formats, duplicate rows, and outliers.
#
# We will pay particular attention to missing values and data formats. For
# example, we will check that dates use a consistent format and that numbers
# are stored as numbers rather than text. We will decide how to handle missing
# values based on the column and document any values we fill in or rows we remove.
#
# We will examine outliers to determine whether they are valid observations or
# data errors. After cleaning the data, we may use feature engineering to create
# useful new variables from existing columns, such as extracting the month from
# a date, if they help answer our analysis question.
#
# These steps help us obtain more accurate and reliable results. Dirty data can
# produce misleading outputs and incorrect conclusions.

# %% [markdown]
# ## Communication and collaboration
#
# We use Microsoft Teams for meetings and project discussions. We share project
# files through GitHub so group members can access and contribute to the work.
# We also use a WhatsApp group for quick updates, questions, and task coordination.
#
# **GitHub repository:** https://github.com/tewelde05/Prog8431--26F---Sec1---Group-2

# %% [markdown]
# ## Case Overview

# %% [markdown]
# Requirement: Using Class and Method to write code

# %% [markdown]
# ## Challenge 5: Mean, Median, and Mode
#
# We will calculate the mean, median, and mode for relevant numerical columns.
# We will use the mode for categorical columns where it makes sense. We will
# compare these measures to understand typical values and check whether outliers
# affect the mean.

# %% [markdown]
# ## Challenge 6: Variance, Standard Deviation, and Quartiles
#
# We will calculate the variance and standard deviation for relevant numerical
# columns to understand how spread out the values are. We will also identify
# the minimum (Q0), first quartile (Q1), median (Q2), third quartile (Q3), and
# maximum (Q4). These values will help us examine the distribution and spot
# potential outliers.

# %% [markdown]
# ## Challenge 7: Data Visualizations
#
# We will use a scatter plot to explore the relationship between two numerical
# variables, a histogram to show the distribution of a numerical variable, and
# a box-and-whisker plot to examine its spread and potential outliers. We will
# use a Venn diagram to show overlap between relevant groups in the dataset.

# %% [markdown]
# ## Challenge 8: Numerical Summary
#
# We will present a numerical summary of relevant columns, including the count,
# mean, standard deviation, minimum, quartiles, and maximum. We will use this
# summary to describe the data and highlight any notable patterns.
